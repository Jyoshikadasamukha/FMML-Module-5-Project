# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyoshikadasamukha/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 07:01:28--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  78.1MB/s    in 0.9s
#
# 2024-04-06 07:01:33 (78.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7705   1802.09511v1  High-dimensional time series data exist in num...  stat
# 2441    1401.3441v1  We develop a technique for deriving data-depen...    cs
# 22646  1703.06476v2  We investigate coresets - succinct, small summ...  stat
# 12919  1710.04382v1  Bayesian inference for models that have an int...  stat
# 19604   1104.0843v3  Phase transitions in many complex combinationa...    cs
# ...             ...                                                ...   ...
# 23652   0906.1763v2  In this paper, we use semi-definite programmin...    cs
# 22021   1311.6182v1  Robust tensor recovery plays an instrumental r...  stat
# 15356   1409.3005v1  Automatic Multi-Word Term (MWT) extraction is ...    cs
# 6467   1702.06354v1  We propose an inlier-based outlier detection m...  stat
# 26413  1610.04062v1  Given a video and its incomplete textural desc...    cs
#
#                                                    title  year  \
# 7705   Missing Data in Sparse Transition Matrix Estim...  2018
# 2441   Transductive Rademacher Complexity and its App...  2014
# 22646  Practical Coreset Constructions for Machine Le...  2017
# 12919  Marginal sequential Monte Carlo for doubly int...  2017
# 19604  Phase Transitions in Knowledge Compilation: an...  2011
# ...                                                  ...   ...
# 23652  Segmentation of Facial Expressions Using Semi-...  2009
# 22021  Robust Low-rank Tensor Recovery: Models and Al...  2013
# 15356  A Study of Association Measures and their Comb...  2014
# 6467   Interpreting Outliers: Localized Logistic Regr...  2017
# 26413         Video Fill in the Blank with Merging LSTMs  2016
#
#                                                 keywords
# 7705   [dimensional, healthcare, neuroscience, unavoi...
# 2441   [technique, dependent, transductive, algorithm...
# 22646  [investigate, summaries, solutions, competitiv...
# 12919  [inference, intractable, partition, intractabl...
# 19604  [transitions, combinational, investigate, tran...
# ...                                                  ...
# 23652  [programming, generalized, principal, componen...
# 22021  [instrumental, robustifying, decompositions, m...
# 15356  [automatic, extraction, important, application...
# 6467   [detection, identifying, explaining, identifyi...
# 26413  [incomplete, description, automatically, conte...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7705     [dimensional, healthcare, neuroscience, unavoi...
# 2441     [technique, dependent, transductive, algorithm...
# 22646    [investigate, summaries, solutions, competitiv...
# 12919    [inference, intractable, partition, intractabl...
# 19604    [transitions, combinational, investigate, tran...
#                                ...
# 10508    [representation, multivariate, distributions, ...
# 6313     [supervised, regression, predictor, variables,...
# 5439     [demonstrated, approximate, programming, funct...
# 34487    [categorization, relevance, initially, documen...
# 5640     [introduce, efficient, principled, backpropaga...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8838 words.
# Out of those 4566 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a628ce08-1b4f-4277-b621-6fca3355a4eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a628ce08-1b4f-4277-b621-6fca3355a4eb")) {                    Plotly.newPlot(                        "a628ce08-1b4f-4277-b621-6fca3355a4eb",                        [{"x":["perspective","observation","regression","healthcare","processes","satisfies","dimensional","covariates","regularized","previously","dependent","underlying","autoregressive","innovation","unavoidable","important","partially","estimating","concentration","interactions","neuroscience","characterizing","dynamical","estimation","transition","applicable","challenges","statistics","theoretical","transductive","demonstrate","applications","algorithms","rademacher","transduction","particular","unlabeled","representation","technique","effectiveness","complexity","empirical","principal","parametric","solutions","investigate","component","construction","practical","clustering","construct","summarize","summaries","intuition","minimization","framework","likelihood","constructions","competitive","theoretically","sequential","techniques","inference","alternative","partition","estimates","distributions","progresses","describes","development","importance","sequences","adaptively","tempering","algorithm","computation","intractable","auxiliary","approaches","investigated","approximate","posteriors","including","empirically","polynomial","compilation","knowledge","experimental","intensive","exponentially","analyzing","exponential","following","conclusions","variables","combinational","transitions","languages","experiments","separates","instances","regardless","reinforcement","furthermore","parameters","architecture","transformations","connections","controller","exceeding","exploration","computational","difficult","noticeable","approaching","automatically","resources","validated","limitation","branching","benchmark","preserving","efficient","designing","restricted","transformation","architectures","promising","outperform","exploring","convolutional","inefficient","potential","unsupervised","recognizing","retrieval","collection","contrasted","pointwise","discusses","evaluated","questions","similarity","implications","information","statistical","collected","outperforms","reflections","significantly","synthetic","reflection","transparent","extensive","synthesize","formation","challenging","separating","realistic","effective","corresponds","relaxation","providing","prediction","justification","replacement","looseness","multilabel","simulations","conducting","satisfied","tremendous","ensembles","comparing","datapoint","procedure","projected","reduction","recurring","dimensionality","advantage","generated","introduce","performed","truncation","therefore","traditional","computing","functions","comparable","probability","efficiency","constrained","approximated","differentiability","hamiltonian","associated","truncated","distribution","continuity"],"y":[73,64,114,11,110,13,207,4,33,74,79,121,5,5,4,326,42,63,9,71,10,16,23,214,26,48,101,49,178,8,542,421,629,6,3,279,39,377,244,210,223,154,43,44,138,150,114,55,131,149,106,11,12,17,58,529,64,7,124,40,73,361,210,99,16,67,102,3,89,126,78,102,31,0,845,154,19,18,446,41,100,5,220,70,49,6,340,374,31,21,75,35,79,27,134,5,10,105,653,5,97,13,95,175,250,247,38,42,18,8,60,294,150,4,7,190,69,33,24,12,207,62,383,31,57,61,121,106,96,36,381,16,142,161,41,117,66,4,8,29,137,61,155,27,702,153,71,293,3,277,153,4,9,156,11,18,281,11,63,223,18,27,82,233,10,10,0,4,54,8,12,11,16,72,1,134,23,106,8,62,93,165,332,125,1,145,177,109,210,111,163,172,61,24,2,5,96,10,213,10],"type":"bar"},{"x":["perspective","observation","regression","healthcare","processes","satisfies","dimensional ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4566,), (4566, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Credal</span> <span style=''>nets</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>epistemic</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>irrelevance</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>credal</span> <span style=''>nets</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalise</span> <span style=''>Bayesian</span> <span style=''>nets</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>imprecise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>applying</span> <span style=''>the</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.3827160493827161);'>independence</span> <span style=''>we</span> <span style=''>replace</span> <span style=''>it</span> <span style=''>by</span> <span style=''>the</span> <span style=''>weaker</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>epistemic</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>irrelevance</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>assessments</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>epistemic</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>irrelevance</span> <span style=''>allow</span> <span style=''>us</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>global</span> <span style=''>model</span> <span style=''>out</span> <span style=''>of</span> <span style=''>given</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>models</span> <span style=''>and</span> <span style=''>mention</span> <span style=''>some</span> <span style=''>useful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>The</span> <span style=''>main</span> <span style=''>results</span> <span style=''>and</span> <span style=''>proofs</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.33846153846153854);'>presented</span> <span style=''>using</span> <span style=''>the</span> <span style=''>language</span> <span style=''>of</span> <span style=''>sets</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style=''>gambles</span> <span style=''>which</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>very</span> <span style=''>general</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4579439252336448);'>representing</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>imprecise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>models</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>and</span> <span style=''>Parallel</span> <span style=''>Bayesian</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Effective</span> <span style=''>and</span> <span style=''>accurate</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>burden</span> <span style=''>required</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>stored</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>on</span> <span style=''>one</span> <span style=''>machine</span> <span style=''>Another</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>one</span> <span style=''>may</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encounter</span> <span style=''>is</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>and</span> <span style=''>contaminations</span> <span style=''>that</span> <span style=''>damage</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>quality</span> <span style=''>The</span> <span style=''>parallel</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>strategy</span> <span style=''>divides</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>full</span> <span style=''>data</span> <span style=''>set</span> <span style=''>into</span> <span style=''>roughly</span> <span style=''>equal</span> <span style=''>subsets</span> <span style=''>and</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>on</span> <span style=''>each</span> <span style=''>subset</span> <span style=''>After</span> <span style=''>local</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>this</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>or</span> <span style=''>other</span> <span style=''>modelvariable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>final</span> <span style=''>model</span> <span style=''>by</span> <span style=''>using ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3781512605042018);'>Detecting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlations</span> <span style=''>with</span> <span style=''>Little</span> <span style=''>Memory</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.35632183908045983);'>Communication</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlations</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666667);'>multivariate</span> <span style=''>data</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.31214953271028034);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>Either</span> <span style=''>on</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>memory</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>or</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.35632183908045983);'>communication</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>across</span> <span style=''>several</span> <span style=''>machines</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>a</span> <span style=''>tight</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>between</span> <span style=''>the</span> <span style=''>memorycommunication</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>implying</span> <span style=''>(for</span> <span style=''>example)</span> <span style=''>that</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlations</span> <span style=''>with</span> <span style=''>optimal</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>required</span> <span style=''>memorycommunication</span> <span style=''>bits</span> <span style=''>is</span> <span style=''>at</span> <span style=''>least</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quadratic</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimension</span> <span style=''>Our</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3235294117647059);'>substantially</span> <span style=''>improve</span> <span style=''>those</span> <span style=''>of</span> <span style=''>Shamir</span> <span style=''>2014</span> <span style=''>which</span> <span style=''>studied</span> <span style=''>a</span> <span style=''>similar</span> <span style=''>question</span> <span style=''>in</span> <span style=''>a</span> <span style=''>much</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>setting</span> <span style=''>To</span> <span style=''>the</span> <span style=''>best</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.38492 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approaches</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>has</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attracted</span> <span style=''>much</span> <span style=''>interest</span> <span style=''>as</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>labels</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>at</span> <span style=''>the</span> <span style=''>group</span> <span style=''>level</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>at</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>level</span> <span style=''>Current</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>however</span> <span style=''>do</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>due</span> <span style=''>to</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variability</span> <span style=''>in</span> <span style=''>the</span> <span style=''>groups</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>assumes</span> <span style=''>that</span> <span style=''>small</span> <span style=''>and</span> <span style=''>large</span> <span style=''>groups</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>equally</span> <span style=''>well</span> <span style=''>and</span> <span style=''>should</span> <span style=''>have</span> <span style=''>equal</span> <span style=''>weight</span> <span style=''>in</span> <span style=''>the</span> <span style=''>final</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>We</span> <span style=''>account</span> <span style=''>for</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>when</span> <span style=''>group</span> <span style=''>sizes</span> <span style=''>vary</span> <span style=''>We</span> <span style=''>frame</span> <span style=''>our</span> <span style=''>models</span> <span style=''>in</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>style</span> <span style=''>allowing</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12078152753108348)
# 	challenging (0.09982238010657193)
# 	architecture (0.08774422735346359)
# 	segmentation (0.07886323268206039)
# 	representation (0.13392539964476022)
# 	information (0.24937833037300178)
# 	different (0.2522202486678508)
# 	detection (0.13463587921847248)
# 	convolutional (0.13534635879218473)
# 	recognition (0.13925399644760214)
#
# Some Statistics words are:
# 	convergence (0.1350125944584383)
# 	estimation (0.16926952141057935)
# 	statistical (0.15113350125944586)
# 	variables (0.14659949622166246)
# 	algorithm (0.40302267002518893)
# 	stochastic (0.14105793450881612)
# 	dimensional (0.1853904282115869)
# 	distribution (0.18992443324937028)
# 	inference (0.1959697732997481)
# 	regression (0.18488664987405543)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c6d7b2c3-621b-4d05-bcc2-35d4a0e4e1d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6d7b2c3-621b-4d05-bcc2-35d4a0e4e1d2")) {                    Plotly.newPlot(                        "c6d7b2c3-621b-4d05-bcc2-35d4a0e4e1d2",                        [{"x":["perspective","observation","regression","healthcare","processes","satisfies","dimensional","covariates","regularized","previously","dependent","underlying","autoregressive","innovation","unavoidable","important","partially","estimating","concentration","interactions","neuroscience","characterizing","dynamical","estimation","transition","applicable","challenges","statistics","theoretical","transductive","demonstrate","applications","algorithms","rademacher","transduction","particular","unlabeled","representation","technique","effectiveness","complexity","empirical","principal","parametric","solutions","investigate","component","construction","practical","clustering","construct","summarize","summaries","intuition","minimization","framework","likelihood","constructions","competitive","theoretically","sequential","techniques","inference","alternative","partition","estimates","distributions","progresses","describes","development","importance","sequences","adaptively","tempering","algorithm","computation","intractable","auxiliary","approaches","investigated","approximate","posteriors","including","empirically","polynomial","compilation","knowledge","experimental","intensive","exponentially","analyzing","exponential","following","conclusions","variables","combinational","transitions","languages","experiments","separates","instances","regardless","reinforcement","furthermore","parameters","architecture","transformations","connections","controller","exceeding","exploration","computational","difficult","noticeable","approaching","automatically","resources","validated","limitation","branching","benchmark","preserving","efficient","designing","restricted","transformation","architectures","promising","outperform","exploring","convolutional","inefficient","potential","unsupervised","recognizing","retrieval","collection","contrasted","pointwise","discusses","evaluated","questions","similarity","implications","information","statistical","collected","outperforms","reflections","significantly","synthetic","reflection","transparent","extensive","synthesize","formation","challenging","separating","realistic","effective","corresponds","relaxation","providing","prediction","justification","replacement","looseness","multilabel","simulations","conducting","satisfied","tremendous","ensembles","comparing","datapoint","procedure","projected","reduction","recurring","dimensionality","advantage","generated","introduce","performed","truncation","therefore","traditional","computing","functions","comparable","probability","efficiency","constrained","approximated","differentiability","hamiltonian","associated","truncated","distribution","continuity","implement","maximization","implementation","expectation","segmentation","implements","generalised","sometimes","subgaussian","specialised","stochastic","exceptions","strategies","katehakis","parameter","understanding","cognitive","technologies","cognition","interpretation","environments","perceptual","perception","simulation","structures","activities","narrative","commonsense","interaction","formalisms","encompasses","reasoning","assistive","constructing","preliminary","artificial","immediate","concerned","viewpoint","classification","intelligence","compressing","necessary","assumption","expensive","distances","similarities","representations","randomized","alternating","challenge","appropriate","addressed","application","guarantee","performance","indivi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	tempering
# 	looseness
# 	katehakis
# 	backfitting
# 	parallelisation
# 	practicing
# 	marginalize
# 	maturation
# 	missforest
# 	parametrically
# 	diffeomorphisms
# 	eigenspaces
# 	confounder
# 	sparsifying
# 	neuroimage
# 	timestamps
# 	advantageously
# 	spectroradiometer
# 	dimensionalities
# 	converged
# Some words which never appear in Statistics papers:
# 	compilation
# 	combinational
# 	reflections
# 	reflection
# 	recurring
# 	commonsense
# 	formalisms
# 	assistive
# 	immediate
# 	attentional
# 	comprehensively
# 	alzheimer
# 	electroencephalograms
# 	reordering
# 	professional
# 	coalition
# 	insertion
# 	facilities
# 	localizing
# 	unhealthy

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.056608387333415e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
